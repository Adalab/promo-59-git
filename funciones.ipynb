# %%
<<<<<<< local
def conflictos(): 
    print("quiero ser un conflicto")
=======
print ("¡Hola Conchitas!")
>>>>>>> remote
# Out:
# ¡Hola Conchitas!

# %% [markdown]
# <span style="color:red"><b><<<<<<< local</b></span>

# %%
conflictos()
# Out:
# quiero ser un conflicto

# %% [markdown]
# <span style="color:red"><b>=======</b></span>

# %% [markdown]
# <span style="color:red"><b>>>>>>>> remote</b></span>
